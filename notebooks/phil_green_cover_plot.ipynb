# %%
import geopandas
import numpy as np
import pandas as pd
import bokeh
from bokeh.models import ColumnDataSource, HoverTool, Legend, Span, Tabs, Text, Title
from bokeh.plotting import figure, output_notebook, show
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import rasterio
import georasters as gr
# Out:
# /Users/anandafigueiredo/opt/miniconda3/envs/plotting/lib/python3.11/site-packages/libpysal/cg/alpha_shapes.py:38: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit
# /Users/anandafigueiredo/opt/miniconda3/envs/plotting/lib/python3.11/site-packages/libpysal/cg/alpha_shapes.py:164: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit
# ...

# %%
import rioxarray as rxr
import xarray as xr

dataarray1 = rxr.open_rasterio('/Users/anandafigueiredo/Downloads/Hansen_GFC-2022-v1.10_last_30N_060E.tif')

df1 = dataarray1[0].to_pandas()

# %%
dataarray2 = rxr.open_rasterio('/Users/anandafigueiredo/Downloads/Hansen_GFC-2022-v1.10_last_30N_070E.tif')

df2 = dataarray2[0].to_pandas()

# %%
phil_rough=pd.concat([df1,df2])

# %%
phil_rough.plot()

# %%
#download + add the right file
file = geopandas.readfile('/Users/anandafigueiredo/GitHub/phl_adminboundaries_candidate_exclude_adm3/phl_admbnda_adm0_3part_psa_namria_itos_20200529.shp')
PHILIPPINES_ADM0 = geopandas.read_file('../../data/shapefiles/Philippines/phl_adminboundaries_candidate_exclude_adm3/phl_admbnda_adm0_singlepart_psa_namria_itos_20200529.shp')

# %%
phil = phil_rough.sjoin(file, how='inner')
phil.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jl/k7cllhd16dz_8_8f0hy7ry8c0000gp/T/ipykernel_20533/2896535972.py in ?()
# ----> 1 india_admin = india.sjoin(PHILIPPINES_ADM0, how='inner')
#       2 india_admin.plot()
#
# ~/opt/miniconda3/envs/plotting/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sjoin'

# %%
from rasterio.plot import show

fig, ax = plt.subplots()

extent = [treecover.bounds[0], treecover.bounds[2], treecover.bounds[1], treecover.bounds[3]]
ax = rasterio.plot.show(treecover, extent=extent, ax=ax, cmap="pink")
